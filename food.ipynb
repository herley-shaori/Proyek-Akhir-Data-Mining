# %%
import glob
import cv2
import numpy
import matplotlib.pyplot as plt

class Fitur:
	def __init__(self):
		labels = ['bubur_ayam','gado_gado','kerak_telor', 'ketoprak', 'kue_cincin', 'kue_rangi','opor_ayam','pindang_bandeng','roti_buaya','soto_betawi','tumis_peda']

		self.images_in_all_folder = []
		print("HAI")
        
		for x in labels:
			images_in_one_folder = [cv2.imread(file) for file in glob.glob('data/'+x+'/*.jpg')]
			self.images_in_all_folder.append(images_in_one_folder)
            
		a = self.images_in_all_folder[0]
		b = a[0]
		img = cv2.cvtColor(b, cv2.COLOR_BGR2RGB)
		plt.imshow(img)        
# 		cv2.imshow('image',b)
# 		cv2.waitKey(0)
# 		cv2.destroyAllWindows()

		self.histograms()

	def histograms(self):
		print("Haloo dari Histogram")
# Out:
#   File "<ipython-input-1-a2e1381932ff>", line 11
#     print("HAI")
#                 ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
# from fitur_makanan import Fitur
fitur_makan = Fitur()
# Out:
# Haloo dari Histogram
